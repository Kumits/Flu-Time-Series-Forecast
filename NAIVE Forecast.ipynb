# %%
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
import pandas as pd
# Out:
# C:\Users\Laptop\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
dane = pd.read_csv('C:/Users/Laptop/Desktop/Grypa/Dane/total.csv', index_col='data')
dane1 = dane[(dane.index > '2012-08-16' ) & (dane.index < '2020-03-16')]

len(dane1)
series = dane1['Total']
series = concat([series.shift(1), series], axis=1)
series.columns = ['t-1', 't+1']
#del series['data']
series
# Out:
#                  t-1     t+1
# data
# 2012-08-23       NaN    9932
# 2012-09-01    9932.0   10530
# 2012-09-08   10530.0   14375
# 2012-09-16   14375.0   23150
# 2012-09-23   23150.0   27864
# ...              ...     ...
# 2020-02-08  193482.0  200194
# 2020-02-16  200194.0  211983
# 2020-02-23  211983.0  215994
# 2020-03-01  215994.0  211572
# 2020-03-08  211572.0  158677
#
# [363 rows x 2 columns]

# %%
X=series.values
X
# Out:
# array([[    nan,   9932.],
#        [  9932.,  10530.],
#        [ 10530.,  14375.],
#        [ 14375.,  23150.],
#        [ 23150.,  27864.],
#        [ 27864.,  34232.],
#        [ 34232.,  45357.],
#        [ 45357.,  43668.],
#        [ 43668.,  56433.],
#        [ 56433.,  46712.],
#        [ 46712.,  50854.],
#        [ 50854.,  47865.],
#        [ 47865.,  58867.],
#        [ 58867.,  58130.],
#        [ 58130.,  61968.],
#        [ 61968.,  62147.],
#        [ 62147.,  78779.],
#        [ 78779., 134358.],
#        [134358., 213906.],
#        [213906., 209903.],
#        [209903., 219511.],
#        [219511., 150439.],
#        [150439., 135150.],
#        [135150., 109313.],
#        [109313.,  77151.],
#        [ 77151.,  87372.],
#        [ 87372., 100518.],
#        [100518., 101205.],
#        [101205.,  91358.],
#        [ 91358.,  75947.],
#        [ 75947.,  81863.],
#        [ 81863.,  60122.],
#        [ 60122.,  44866.],
#        [ 44866.,  30305.],
# ...

# %%
#series

# %%
X= series.values
train, test = X[1:267], X[267:]
#train

# %%
train_x, train_y = train[:,0], train[:,1]

# %%
test_x, test_y = test[:,0], test[:,1]

# %%
#train_x

# %%
#train_y

# %%
#test_x

# %%
#test_y

# %%
def model_persistence(x):
    return x

# %%
predictions=list()
for x in train_x:
    wynik = model_persistence(x)
    predictions.append(wynik)
test_score = mean_squared_error(train_y, predictions)
print('Residual: %.3f' % test_score)
# Out:
# Residual: 414751537.086

# %%
predictions=list()
for x in test_x:
    wynik = model_persistence(x)
    predictions.append(wynik)
test_score = mean_squared_error(test_y, predictions)
print('MSE: %.3f' % test_score)
# Out:
# MSE: 480572958.646
